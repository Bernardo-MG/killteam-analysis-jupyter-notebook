# %% [markdown]
# # Kill Team Damage Calculations

# %%
import pandas as pd
from scripts.dice import average_dice_value
from scripts.values import user_value
from scripts.killteam import chance_to_hit, chance_to_wound, chance_to_fail_armour, chance_to_damage, chance_to_damage_at_least_once

weapons_average = pd.read_csv('datasets/1st/weapons.csv')
weapons_average = weapons_average.sort_values(by=['name'])

# %%
average_strength = 3
average_attacks = 1
average_ballistics = 3
average_toughness = 3
average_armor = 5

# %% [markdown]
# ## Averages

# %%
weapons_average["attacks"] = weapons_average.apply(lambda x: average_dice_value(x["attacks"]), axis=1)
weapons_average["damage"] = weapons_average.apply(lambda x: average_dice_value(x["damage"]), axis=1)

# %%
weapons_average["attacks"] = weapons_average.apply(lambda x: user_value(x["attacks"], average_attacks), axis=1)
weapons_average["strength"] = weapons_average.apply(lambda x: user_value(x["strength"], average_strength), axis=1)

# %%
weapons_average
# Out:
#                             name attacks strength  ap damage
# 16              Barbed strangler       3        5  -1      1
# 0                    Bolt pistol       1        4   0      1
# 1                     Bolt rifle       1        4  -1      1
# 2                        Boltgun       1        4   0      1
# 17                  Deathspitter       3        5  -1      1
# 18                      Devourer       3        4   0      1
# 19                   Flesh hooks       2        3   0      1
# 20                    Fleshborer       1        4   0      1
# 12                Galvanic rifle       1        4   0      1
# 3                         Lasgun       1        3   0      1
# 4                      Laspistol       1        3   0      1
# 5                       Meltagun       1        8  -4      3
# 10     Plasma caliver (standard)       2        7  -3      1
# 11  Plasma caliver (supercharge)       2        8  -3      2
# 6          Plasma gun (standard)       1        7  -3      1
# 7       Plasma gun (supercharge)       1        8  -3      2
# 8       Plasma pistol (standard)       1        7  -3      1
# 9    Plasma pistol (supercharge)       1        8  -3      2
# 13                Radium carbine       3        3   0      1
# 14                 Radium pistol       1        3   0      1
# 15                  Sniper rifle       1        4   0      1
# 21                    Spinefists       1        3   0      1
# 22                  Venom cannon       2        8  -2      2

# %% [markdown]
# ## Hit chance

# %%
weapons_average["to_hit"] = weapons_average.apply(lambda x: chance_to_hit(average_ballistics), axis=1)
weapons_average["to_wound"] = weapons_average.apply(lambda x: chance_to_wound(int(x["strength"]), average_toughness), axis=1)
weapons_average["to_fail_armor"] = weapons_average.apply(lambda x: chance_to_fail_armour(int(x["ap"]), average_armor), axis=1)
weapons_average["to_damage"] = weapons_average.apply(lambda x: chance_to_damage(float(x["to_hit"]), float(x["to_wound"]), float(x["to_fail_armor"])), axis=1)
weapons_average["to_damage_at_least_once"] = weapons_average.apply(lambda x: chance_to_damage_at_least_once(float(x["to_damage"]), float(x["attacks"])), axis=1)

# %%
weapons_average
# Out:
#                             name attacks strength  ap damage  \
# 16              Barbed strangler       3        5  -1      1
# 0                    Bolt pistol       1        4   0      1
# 1                     Bolt rifle       1        4  -1      1
# 2                        Boltgun       1        4   0      1
# 17                  Deathspitter       3        5  -1      1
# 18                      Devourer       3        4   0      1
# 19                   Flesh hooks       2        3   0      1
# 20                    Fleshborer       1        4   0      1
# 12                Galvanic rifle       1        4   0      1
# 3                         Lasgun       1        3   0      1
# 4                      Laspistol       1        3   0      1
# 5                       Meltagun       1        8  -4      3
# 10     Plasma caliver (standard)       2        7  -3      1
# 11  Plasma caliver (supercharge)       2        8  -3      2
# 6          Plasma gun (standard)       1        7  -3      1
# 7       Plasma gun (supercharge)       1        8  -3      2
# 8       Plasma pistol (standard)       1        7  -3      1
# 9    Plasma pistol (supercharge)       1        8  -3      2
# 13                Radium carbine       3        3   0      1
# 14                 Radium pistol       1        3   0      1
# 15                  Sniper rifle       1        4   0      1
# 21                    Spinefists       1        3   0      1
# 22                  Venom cannon       2        8  -2      2
#
#                to_hit           to_wound      to_fail_armor  \
# 16  66.66666666666666  66.66666666666666  83.33333333333334
# 0   66.66666666666666  66.66666666666666  66.66666666666667
# 1   66.66666666666666  66.66666666666666  83.33333333333334
# 2   66.66666666666666  66.66666666666666  66.66666666666667
# 17  66.66666666666666  66.66666666666666  83.33333333333334
# 18  66.66666666666666  66.66666666666666  66.66666666666667
# 19  66.66666666666666               50.0  66.66666666666667
# 20  66.66666666666666  66.66666666666666  66.66666666666667
# 12  66.66666666666666  66.66666666666666  66.66666666666667
# 3   66.66666666666666               50.0  66.66666666666667
# 4   66.66666666666666               50.0  66.66666666666667
# 5   66.66666666666666  83.33333333333334                100
# 10  66.66666666666666  83.33333333333334                100
# 11  66.66666666666666  83.33333333333334                100
# 6   66.66666666666666  83.33333333333334                100
# 7   66.66666666666666  83.33333333333334                100
# 8   66.66666666666666  83.33333333333334                100
# 9   66.66666666666666  83.33333333333334                100
# 13  66.66666666666666               50.0  66.66666666666667
# 14  66.66666666666666               50.0  66.66666666666667
# 15  66.66666666666666  66.66666666666666  66.66666666666667
# 21  66.66666666666666               50.0  66.66666666666667
# 22  66.66666666666666  83.33333333333334              100.0
#
#              to_damage        to_damage_at_least_once
# 16   37.03703703703703  75.03937407915458601692648699
# 0   29.629629629629623  29.62962962962962798485477833
# 1    37.03703703703703  37.03703703703702387883822666
# 2   29.629629629629623  29.62962962962962798485477833
# 17   37.03703703703703  75.03937407915458601692648699
# 18  29.629629629629623  65.15266981659300071783036401
# 19   22.22222222222222  39.50617283950617064647303778
# 20  29.629629629629623  29.62962962962962798485477833
# 12  29.629629629629623  29.62962962962962798485477833
# 3    22.22222222222222  22.22222222222222098864108375
# 4    22.22222222222222  22.22222222222222098864108375
# 5    55.55555555555556  55.55555555555555802271783250
# 10   55.55555555555556  80.24691358024691467676348111
# 11   55.55555555555556  80.24691358024691467676348111
# 6    55.55555555555556  55.55555555555555802271783250
# 7    55.55555555555556  55.55555555555555802271783250
# 8    55.55555555555556  55.55555555555555802271783250
# 9    55.55555555555556  55.55555555555555802271783250
# 13   22.22222222222222  52.94924554183813025787230799
# 14   22.22222222222222  22.22222222222222098864108375
# 15  29.629629629629623  29.62962962962962798485477833
# 21   22.22222222222222  22.22222222222222098864108375
# 22   55.55555555555556  80.24691358024691467676348111
